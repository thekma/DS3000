# %%
import pandas as pd

# %%
df = pd.read_csv("mass_2019.csv")

# %%
df.head()
# Out:
#                                          case                  location  \
# 0               Odessa-Midland shooting spree             Odessa, Texas
# 1      Dayton entertainment district shooting                Dayton, OH
# 2               El Paso Walmart mass shooting            El Paso, Texas
# 3             Gilroy garlic festival shooting                Gilroy, CA
# 4  Virginia Beach municipal building shooting  Virginia Beach, Virginia
#
#         date                                            summary  fatalities  \
# 0  8/31/2019  Seth A. Ator, 36, fired at police officers who...           7
# 1   8/4/2019  Connor Betts, 24, died during the attack, foll...           9
# 2   8/3/2019  Patrick Crusius, 21, who was apprehended by po...          22
# 3  7/28/2019  Santino William LeGan, 19, fired indiscriminat...           3
# 4  5/31/2019  DeWayne Craddock, 40, a municipal city worker ...          12
#
#    injured  total_victims location.1  age_of_shooter  \
# ...

# %%
columns_needed = ["case", "location", "date", "fatalities", "injured", "total_victims", 'type', 'year']

# %% [markdown]
# ### 1. Obtain a new DF containing the columns above

# %%
df2 = df[columns_needed]
df2
# Out:
#                                               case  \
# 0                    Odessa-Midland shooting spree
# 1           Dayton entertainment district shooting
# 2                    El Paso Walmart mass shooting
# 3                  Gilroy garlic festival shooting
# 4       Virginia Beach municipal building shooting
# 5               Harry Pratt Co. warehouse shooting
# 6                  Pennsylvania hotel bar shooting
# 7                           SunTrust bank shooting
# 8                          Mercy Hospital shooting
# 9                 Thousand Oaks nightclub shooting
# 10                 Tree of Life synagogue shooting
# 11                     Rite Aid warehouse shooting
# 12                           T&T Trucking shooting
# 13                     Fifth Third Center shooting
# 14                        Capital Gazette shooting
# 15                   Santa Fe High School shooting
# 16                           Waffle House shooting
# ...

# %% [markdown]
# ### 2. Keep rows if the type of the case is Mass (mass shooting)

# %%
df2[df['type'] == 'Mass']
# Out:
#                                               case  \
# 1           Dayton entertainment district shooting
# 2                    El Paso Walmart mass shooting
# 3                  Gilroy garlic festival shooting
# 4       Virginia Beach municipal building shooting
# 5               Harry Pratt Co. warehouse shooting
# 7                           SunTrust bank shooting
# 8                          Mercy Hospital shooting
# 9                 Thousand Oaks nightclub shooting
# 10                 Tree of Life synagogue shooting
# 11                     Rite Aid warehouse shooting
# 13                     Fifth Third Center shooting
# 14                        Capital Gazette shooting
# 15                   Santa Fe High School shooting
# 16                           Waffle House shooting
# 17               Yountville veterans home shooting
# 18   Marjory Stoneman Douglas High School shooting
# 19                   Pennsylvania carwash shooting
# ...

# %%
df[df['type'] == 'Mass']
# Out:
#                                               case  \
# 1           Dayton entertainment district shooting
# 2                    El Paso Walmart mass shooting
# 3                  Gilroy garlic festival shooting
# 4       Virginia Beach municipal building shooting
# 5               Harry Pratt Co. warehouse shooting
# 7                           SunTrust bank shooting
# 8                          Mercy Hospital shooting
# 9                 Thousand Oaks nightclub shooting
# 10                 Tree of Life synagogue shooting
# 11                     Rite Aid warehouse shooting
# 13                     Fifth Third Center shooting
# 14                        Capital Gazette shooting
# 15                   Santa Fe High School shooting
# 16                           Waffle House shooting
# 17               Yountville veterans home shooting
# 18   Marjory Stoneman Douglas High School shooting
# 19                   Pennsylvania carwash shooting
# ...

# %% [markdown]
# ### 3. Set case as the index of the DF

# %%
df2.set_index('case')
# Out:
#                                                                            location  \
# case
# Odessa-Midland shooting spree                                         Odessa, Texas
# Dayton entertainment district shooting                                   Dayton, OH
# El Paso Walmart mass shooting                                        El Paso, Texas
# Gilroy garlic festival shooting                                          Gilroy, CA
# Virginia Beach municipal building shooting                 Virginia Beach, Virginia
# Harry Pratt Co. warehouse shooting                                 Aurora, Illinois
# Pennsylvania hotel bar shooting                         State College, Pennsylvania
# SunTrust bank shooting                                             Sebring, Florida
# Mercy Hospital shooting                                           Chicago, Illinois
# Thousand Oaks nightclub shooting                                  Thousand Oaks, CA
# ...

# %%
df.set_index('case')
# Out:
#                                                                            location  \
# case
# Odessa-Midland shooting spree                                         Odessa, Texas
# Dayton entertainment district shooting                                   Dayton, OH
# El Paso Walmart mass shooting                                        El Paso, Texas
# Gilroy garlic festival shooting                                          Gilroy, CA
# Virginia Beach municipal building shooting                 Virginia Beach, Virginia
# Harry Pratt Co. warehouse shooting                                 Aurora, Illinois
# Pennsylvania hotel bar shooting                         State College, Pennsylvania
# SunTrust bank shooting                                             Sebring, Florida
# Mercy Hospital shooting                                           Chicago, Illinois
# Thousand Oaks nightclub shooting                                  Thousand Oaks, CA
# ...

# %% [markdown]
# ### 4. Obtain State Names from Location
# * Extract State names from location

# %%
for loc_st in df2['location']:
    print(loc_st.split(1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-6ee64748d256> in <module>()
#       1 for loc_st in df2['location']:
# ----> 2     print(loc_st.split(1))
#
# TypeError: must be str or None, not int

# %% [markdown]
# ### 5. List of cases in which the number of fatalities was greater than that of injured

# %% [markdown]
# ### 6. Number of cases in which the number of fatalities was greater than that of injured

# %% [markdown]
# ### 7. Name of the deadliest mass shooting case (with greatest number of fatalities)

# %% [markdown]
# ### 8. Total number of fatalities in mass shootings taking place in Texas

# %% [markdown]
# ### 9. Total number of fatalities in mass shootings taking place in 2019
