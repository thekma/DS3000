# %%
import pandas as pd
df = pd.read_csv("Sexual_Assault_Data.csv")
df.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   571533282     12/31/18     17:05:00     12/31/18     17:15:00
# 1   820453504     12/31/18     15:35:00     12/31/18     15:40:00
# 2   113940766     12/31/18      4:30:00     12/31/18      4:50:00
# 3   817554319     12/30/18      3:30:00     12/30/18      3:45:00
# 4   726764710     12/30/18     18:45:00     12/30/18     19:00:00
#
#    ADDR_PCT_CD    RPT_DT  KY_CD   OFNS_DESC PD_CD  ... SUSP_SEX  \
# 0           10  12/31/18    233  SEX CRIMES   175  ...        M
# 1           40  12/31/18    233  SEX CRIMES   175  ...      NaN
# 2           49  12/31/18    233  SEX CRIMES   175  ...        M
# 3           34  12/30/18    233  SEX CRIMES   175  ...        M
# 4          120  12/30/18    233  SEX CRIMES   175  ...      NaN
#
#   TRANSIT_DISTRICT   Latitude  Longitude                        Lat_Lon  \
# 0              NaN  40.742699 -73.998655   (40.742699299, -73.99865538)
# 1              NaN  40.810396 -73.925311  (40.810396019, -73.925310745)
# 2              NaN  40.856163 -73.844397  (40.856162957, -73.844397124)
# 3              3.0  40.851488 -73.935458  (40.851487774, -73.935457967)
# 4              NaN  40.644726 -74.077483  (40.644726131, -74.077483159)
#
#                  PATROL_BORO    STATION_NAME  VIC_AGE_GROUP  \
# 0      PATROL BORO MAN SOUTH             NaN            <18
# 1          PATROL BORO BRONX             NaN          25-44
# 2          PATROL BORO BRONX             NaN          18-24
# 3      PATROL BORO MAN NORTH  207 ST.-INWOOD          25-44
# 4  PATROL BORO STATEN ISLAND             NaN          25-44
#
#                    VIC_RACE VIC_SEX
# 0                     WHITE       M
# 1            WHITE HISPANIC       F
# 2            WHITE HISPANIC       F
# 3                   UNKNOWN       M
# 4  ASIAN / PACIFIC ISLANDER       F
#
# [5 rows x 35 columns]

# %%
df = df.drop(columns = ["PD_CD", "PARKS_NM", "HADEVELOPT", "HOUSING_PSA", "OFNS_DESC", "RPT_DT", "VIC_AGE_GROUP", "CMPLNT_TO_DT", "CMPLNT_TO_TM", "PATROL_BORO", "LOC_OF_OCCUR_DESC","TRANSIT_DISTRICT"])

# %%
df.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD  KY_CD           PD_DESC  \
# 0   571533282     12/31/18     17:05:00           10    233  SEXUAL ABUSE 3,2
# 1   820453504     12/31/18     15:35:00           40    233  SEXUAL ABUSE 3,2
# 2   113940766     12/31/18      4:30:00           49    233  SEXUAL ABUSE 3,2
# 3   817554319     12/30/18      3:30:00           34    233  SEXUAL ABUSE 3,2
# 4   726764710     12/30/18     18:45:00          120    233  SEXUAL ABUSE 3,2
#
#   CRM_ATPT_CPTD_CD   LAW_CAT_CD        BORO_NM         PREM_TYP_DESC  ...  \
# 0        COMPLETED  MISDEMEANOR      MANHATTAN                STREET  ...
# 1        COMPLETED  MISDEMEANOR          BRONX     BUS (NYC TRANSIT)  ...
# 2        COMPLETED  MISDEMEANOR          BRONX       RESIDENCE-HOUSE  ...
# 3        COMPLETED  MISDEMEANOR      MANHATTAN  TRANSIT - NYC SUBWAY  ...
# 4        COMPLETED  MISDEMEANOR  STATEN ISLAND     BUS (NYC TRANSIT)  ...
#
#   Y_COORD_CD  SUSP_AGE_GROUP SUSP_RACE SUSP_SEX   Latitude  Longitude  \
# 0    209,859         UNKNOWN     WHITE        M  40.742699 -73.998655
# 1    234,532             NaN       NaN      NaN  40.810396 -73.925311
# 2    251,236         UNKNOWN   UNKNOWN        M  40.856163 -73.844397
# 3    249,501           25-44     WHITE        M  40.851488 -73.935458
# 4    174,174             NaN       NaN      NaN  40.644726 -74.077483
#
#                          Lat_Lon    STATION_NAME                  VIC_RACE  \
# 0   (40.742699299, -73.99865538)             NaN                     WHITE
# 1  (40.810396019, -73.925310745)             NaN            WHITE HISPANIC
# 2  (40.856162957, -73.844397124)             NaN            WHITE HISPANIC
# 3  (40.851487774, -73.935457967)  207 ST.-INWOOD                   UNKNOWN
# 4  (40.644726131, -74.077483159)             NaN  ASIAN / PACIFIC ISLANDER
#
#   VIC_SEX
# 0       M
# 1       F
# 2       F
# 3       M
# 4       F
#
# [5 rows x 23 columns]

# %%
# df["LAW_CAT_CD"].value_counts()

target = []

for i, r in df.iterrows():
    if r["LAW_CAT_CD"] == "MISDEMEANOR":
        target.append(0)
    else: 
        target.append(1)
        
df["target"] = target

df
# Out:
#       CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD  KY_CD  \
# 0      571533282     12/31/18     17:05:00           10    233
# 1      820453504     12/31/18     15:35:00           40    233
# 2      113940766     12/31/18      4:30:00           49    233
# 3      817554319     12/30/18      3:30:00           34    233
# 4      726764710     12/30/18     18:45:00          120    233
# ...          ...          ...          ...          ...    ...
# 8768   852905557      9/22/16     10:00:00           10    233
# 8769   403919471      9/22/16     14:15:00           47    233
# 8770   755552208      9/22/16     16:30:00          105    233
# 8771   681712179      9/22/16      9:00:00           40    233
# 8772   141095242      9/21/16     22:29:00            1    233
#
#                             PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD  \
# 0                  SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 1                  SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 2                  SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 3                  SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 4                  SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# ...                             ...              ...          ...
# 8768               SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 8769               SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 8770  SEXUAL MISCONDUCT,INTERCOURSE        ATTEMPTED  MISDEMEANOR
# 8771               SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 8772               SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
#
#             BORO_NM           PREM_TYP_DESC  ... SUSP_AGE_GROUP  \
# 0         MANHATTAN                  STREET  ...        UNKNOWN
# 1             BRONX       BUS (NYC TRANSIT)  ...            NaN
# 2             BRONX         RESIDENCE-HOUSE  ...        UNKNOWN
# 3         MANHATTAN    TRANSIT - NYC SUBWAY  ...          25-44
# 4     STATEN ISLAND       BUS (NYC TRANSIT)  ...            NaN
# ...             ...                     ...  ...            ...
# 8768      MANHATTAN    TRANSIT - NYC SUBWAY  ...          25-44
# 8769          BRONX           PUBLIC SCHOOL  ...            NaN
# 8770         QUEENS         RESIDENCE-HOUSE  ...          18-24
# 8771          BRONX  RESIDENCE - APT. HOUSE  ...        UNKNOWN
# 8772      MANHATTAN                   OTHER  ...          18-24
#
#            SUSP_RACE SUSP_SEX   Latitude  Longitude  \
# 0              WHITE        M  40.742699 -73.998655
# 1                NaN      NaN  40.810396 -73.925311
# 2            UNKNOWN        M  40.856163 -73.844397
# 3              WHITE        M  40.851488 -73.935458
# 4                NaN      NaN  40.644726 -74.077483
# ...              ...      ...        ...        ...
# 8768           BLACK        M  40.742699 -73.998655
# 8769             NaN      NaN  40.887451 -73.847608
# 8770           BLACK        M  40.726187 -73.735234
# 8771         UNKNOWN        U  40.810396 -73.925311
# 8772  BLACK HISPANIC        M  40.720255 -74.007090
#
#                             Lat_Lon    STATION_NAME                  VIC_RACE  \
# 0      (40.742699299, -73.99865538)             NaN                     WHITE
# 1     (40.810396019, -73.925310745)             NaN            WHITE HISPANIC
# 2     (40.856162957, -73.844397124)             NaN            WHITE HISPANIC
# 3     (40.851487774, -73.935457967)  207 ST.-INWOOD                   UNKNOWN
# 4     (40.644726131, -74.077483159)             NaN  ASIAN / PACIFIC ISLANDER
# ...                             ...             ...                       ...
# 8768   (40.742699299, -73.99865538)       14 STREET                     WHITE
# 8769  (40.887451313, -73.847607787)             NaN            WHITE HISPANIC
# 8770   (40.72618713, -73.735233904)             NaN                     BLACK
# 8771  (40.810396019, -73.925310745)             NaN            BLACK HISPANIC
# 8772   (40.720255223, -74.00709028)             NaN                     WHITE
#
#       VIC_SEX target
# 0           M      1
# 1           F      1
# 2           F      1
# 3           M      1
# 4           F      1
# ...       ...    ...
# 8768        F      1
# 8769        F      1
# 8770        F      1
# 8771        M      1
# 8772        F      1
#
# [8773 rows x 24 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

BBox = [df.Longitude.min(), df.Longitude.max(),      
         df.Latitude.min(), df.Latitude.max()]
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df.Longitude, df.Latitude, zorder=1, alpha= 0.2, c='b', s=5)
ax.set_title('Plotting Spatial Data on NYC Map')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-2695e652413a> in <module>
#      10 ax.set_xlim(BBox[0],BBox[1])
#      11 ax.set_ylim(BBox[2],BBox[3])
# ---> 12 ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')
#
# NameError: name 'ruh_m' is not defined

# %%
import numpy as np
df1 = df.replace(np.nan, 'UNKNOWN', regex=True)

# %%
df1
# Out:
#       CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD  KY_CD  \
# 0      571533282     12/31/18     17:05:00           10    233
# 1      820453504     12/31/18     15:35:00           40    233
# 2      113940766     12/31/18      4:30:00           49    233
# 3      817554319     12/30/18      3:30:00           34    233
# 4      726764710     12/30/18     18:45:00          120    233
# ...          ...          ...          ...          ...    ...
# 8768   852905557      9/22/16     10:00:00           10    233
# 8769   403919471      9/22/16     14:15:00           47    233
# 8770   755552208      9/22/16     16:30:00          105    233
# 8771   681712179      9/22/16      9:00:00           40    233
# 8772   141095242      9/21/16     22:29:00            1    233
#
#                             PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD  \
# 0                  SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 1                  SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 2                  SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 3                  SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 4                  SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# ...                             ...              ...          ...
# 8768               SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 8769               SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 8770  SEXUAL MISCONDUCT,INTERCOURSE        ATTEMPTED  MISDEMEANOR
# 8771               SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
# 8772               SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
#
#             BORO_NM           PREM_TYP_DESC  ... SUSP_AGE_GROUP  \
# 0         MANHATTAN                  STREET  ...        UNKNOWN
# 1             BRONX       BUS (NYC TRANSIT)  ...        UNKNOWN
# 2             BRONX         RESIDENCE-HOUSE  ...        UNKNOWN
# 3         MANHATTAN    TRANSIT - NYC SUBWAY  ...          25-44
# 4     STATEN ISLAND       BUS (NYC TRANSIT)  ...        UNKNOWN
# ...             ...                     ...  ...            ...
# 8768      MANHATTAN    TRANSIT - NYC SUBWAY  ...          25-44
# 8769          BRONX           PUBLIC SCHOOL  ...        UNKNOWN
# 8770         QUEENS         RESIDENCE-HOUSE  ...          18-24
# 8771          BRONX  RESIDENCE - APT. HOUSE  ...        UNKNOWN
# 8772      MANHATTAN                   OTHER  ...          18-24
#
#            SUSP_RACE SUSP_SEX TRANSIT_DISTRICT Latitude Longitude  \
# 0              WHITE        M          UNKNOWN  40.7427  -73.9987
# 1            UNKNOWN  UNKNOWN          UNKNOWN  40.8104  -73.9253
# 2            UNKNOWN        M          UNKNOWN  40.8562  -73.8444
# 3              WHITE        M                3  40.8515  -73.9355
# 4            UNKNOWN  UNKNOWN          UNKNOWN  40.6447  -74.0775
# ...              ...      ...              ...      ...       ...
# 8768           BLACK        M                2  40.7427  -73.9987
# 8769         UNKNOWN  UNKNOWN          UNKNOWN  40.8875  -73.8476
# 8770           BLACK        M          UNKNOWN  40.7262  -73.7352
# 8771         UNKNOWN        U          UNKNOWN  40.8104  -73.9253
# 8772  BLACK HISPANIC        M          UNKNOWN  40.7203  -74.0071
#
#                             Lat_Lon    STATION_NAME                  VIC_RACE  \
# 0      (40.742699299, -73.99865538)         UNKNOWN                     WHITE
# 1     (40.810396019, -73.925310745)         UNKNOWN            WHITE HISPANIC
# 2     (40.856162957, -73.844397124)         UNKNOWN            WHITE HISPANIC
# 3     (40.851487774, -73.935457967)  207 ST.-INWOOD                   UNKNOWN
# 4     (40.644726131, -74.077483159)         UNKNOWN  ASIAN / PACIFIC ISLANDER
# ...                             ...             ...                       ...
# 8768   (40.742699299, -73.99865538)       14 STREET                     WHITE
# 8769  (40.887451313, -73.847607787)         UNKNOWN            WHITE HISPANIC
# 8770   (40.72618713, -73.735233904)         UNKNOWN                     BLACK
# 8771  (40.810396019, -73.925310745)         UNKNOWN            BLACK HISPANIC
# 8772   (40.720255223, -74.00709028)         UNKNOWN                     WHITE
#
#      VIC_SEX
# 0          M
# 1          F
# 2          F
# 3          M
# 4          F
# ...      ...
# 8768       F
# 8769       F
# 8770       F
# 8771       M
# 8772       F
#
# [8773 rows x 24 columns]
